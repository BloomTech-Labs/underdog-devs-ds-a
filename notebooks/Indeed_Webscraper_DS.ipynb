# %%
import requests
import bs4
from bs4 import BeautifulSoup

import pandas as pd
import time
import copy
import csv

# %%
def get_url(position):
  '''Function to search a position on the Indeed webpage'''
  template = 'https://www.indeed.com/jobs?q={}&l'
  url = template.format(position)
  
  return url

# %%
def response_func(url):
  '''Function returns a get request for html of an indeed webpage'''
  response = requests.get(url, headers={'User-Agent': 'test'})

  return response

# %%
def get_cards(response):
  ''' Indeed search results are divided up by cards.
      This function returns the cards get_job_cards for each job title'
  '''
  soup = BeautifulSoup(response.text, 'html.parser')
  cards = soup.find_all('td', {'class': 'resultContent'})

  return cards

# %%
def get_job_title(card):
  '''Function returns the job title'''
  job_title = card.find_all('span')[1].get_text()
  
  return job_title

# %%
def get_job_url(card):
  '''Function returns the job posting url'''
  try:
    job_url = 'https://www.indeed.com' + card.h2.a.get('href')
    return job_url
  except AttributeError:
    return 'https://www.indeed.com/404'

# %%
def get_company_name(card):
  '''Function returns the company name who posted the job'''
  company = card.find('span', 'companyName').text

  return company

# %%
def get_location(card):
  '''Function returns the job location'''
  location = card.find('div', 'companyLocation').text

  return location

# %%
def get_job_description(job_url):
  response = requests.get(job_url, headers={'User-Agent': 'test'})
  soup = BeautifulSoup(response.text, 'html.parser')
  try:
    description = soup.find('div', 'jobsearch-jobDescriptionText').text.strip()
    return description
  except AttributeError:
    return "No job description"

# %%
def get_job_records(position):
  '''
  Function returns an array of the following
  * Company Name
  * Job Title
  * Location
  * Descriptions
  * Job Url
  '''
  # Retrieves the data on the first page of the search results

  records = []
  url = get_url(position)
  response = response_func(url)
  while True:
    cards = get_cards(response)
    for card in cards:
      job_title = get_job_title(card)
      company_name = get_company_name(card)
      job_location = get_location(card)
      job_url = get_job_url(card)
      job_description = get_job_description(job_url)

      records.append([job_title,
                      company_name,
                      job_location,
                      job_description,
                      job_url])
    # Goes through each page of the search results
    try:
      response = requests.get(url)
      soup = BeautifulSoup(response.text, 'html.parser')
      url = 'https://www.indeed.com' + soup.find(
                        'a',
                        {'aria=label': 'Next'}
                        ).get('href')
    except AttributeError:
      break
  return records

# %%
search_terms = [
    "data%20scientist",
    "machine%20learning%20engineer",
    "data%20engineer",
    "web%20developer",
    "frontend%20developer",
    "backend%20developer",
    "devops",
    "software%20engineer",
]

# %%
from random import uniform
for position in search_terms:
  time.sleep(uniform(1.1,2.1))
  try:
    scraped_list = get_job_records(position)
    indeed_jobs = pd.DataFrame(scraped_list,
                              columns=[
                                        'Company',
                                        'JobTitle',
                                        'Location',
                                        'Description',
                                        'JobUrl'])
    saving_jobs = copy.deepcopy(indeed_jobs)
    saving_jobs = saving_jobs.drop_duplicates(['Description']).reset_index(drop=True)
    saving_jobs = saving_jobs[saving_jobs['Description'].notna()]
    if len(saving_jobs)==1:
      continue
    display(saving_jobs)

    position = position.replace('%20', '_')

    saving_jobs.to_csv(f'{position}_jobs.csv', encoding='utf-8', index=False)
    print(f'Successfully saved {position} jobs!")')
  except AttributeError:
    print(f'Failed to save {position} jobs check errlogs')
    continue
# Out:
#                                 Company                             JobTitle  \
# 0                                Zillow                               Zillow
# 1                        Talentheed Inc                       Talentheed Inc
# 2                Director, Data Science                                 Hulu
# 3                        Data Scientist          Columbia Sportswear Company
# 4          Data Scientist (Entry-Level)                         GreatSchools
# 5                        Data Scientist                             Best Egg
# 6   Madison Square Garden Entertainment  Madison Square Garden Entertainment
# 7                        Data Scientist                           Comcentric
# 8                           Lark Health                          Lark Health
# 9                           Wealthfront                          Wealthfront
# 10                               Twitch                               Twitch
# 11         Data Scientist, StoreConnect                 Hussmann Corporation
# 12  Senior Data Scientist - 100% Remote                          Pluralsight
# 13                            Pinterest                            Pinterest
# 14                            Starbucks                            Starbucks
#
#                                     Location  \
# 0                                     Remote
# 1                                     Remote
# 2                           Remote in Oregon
# 3                         Portland, OR 97229
# 4                Remote in Oakland, CA 94612
# 5                                     Remote
# 6              Remote in Tarrytown, NY 10591
# 7           Remote in Salem, OR+34 locations
# 8                Remote in Mountain View, CA
# 9   Remote in Palo Alto, CA 94301+1 location
# 10            San Francisco, CA+13 locations
# 11                    Remote in Portland, OR
# 12                                    Remote
# 13                  United States+1 location
# 14         Remote in Seattle, WA+5 locations
#
#                                           Description  \
# 0   About the team About the team \n   We are the ...
# 1   Responsibilities: \n\nData mining or extricati...
# 2   At Disney Streaming, we are experiencing explo...
# 3   OUTGROWN YOUR OWN BACKYARD? COME PLAY IN OURS....
# 4   About GreatSchools.org: GreatSchools is the le...
# 5   is not designed to cover or contain a comprehe...
# 6   Who are we hiring?\n\n As a Basketball Data Sc...
# 7   We are currently seeking a Senior Data Scienti...
# 8   About Lark\n\n\n   Lark is the world's largest...
# 9   Data and its proper use is crucial to that vis...
# 10  About Us\n\nLaunched in 2011, Twitch is a glob...
# 11  Work with the other members of the StoreConnec...
# 12  Job Description:\n  \n\n    Data Scientist — S...
# 13  About Pinterest: \nMillions of people across t...
# 14  Job Posting : Mar 14, 2022 \n   Job Posting En...
#
#                                                JobUrl
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/company/Talentheed-Inc/...
# 2   https://www.indeed.com/rc/clk?jk=8e3e08454a725...
# 3   https://www.indeed.com/rc/clk?jk=74eaf0a8d1ddd...
# 4   https://www.indeed.com/company/GreatSchools/jo...
# 5   https://www.indeed.com/company/Best-Egg/jobs/D...
# 6   https://www.indeed.com/rc/clk?jk=41d2ea80ddeb8...
# 7   https://www.indeed.com/rc/clk?jk=987c988973978...
# 8   https://www.indeed.com/rc/clk?jk=6345333550b73...
# 9   https://www.indeed.com/rc/clk?jk=f436958b48feb...
# 10  https://www.indeed.com/rc/clk?jk=28d74ad0f9306...
# 11  https://www.indeed.com/rc/clk?jk=aaf207af2d622...
# 12  https://www.indeed.com/rc/clk?jk=75792c7b61896...
# 13  https://www.indeed.com/rc/clk?jk=e535508853cf0...
# 14  https://www.indeed.com/rc/clk?jk=f84d4861a4473...
# Successfully saved data_scientist jobs!")
#                                  Company                             JobTitle  \
# 0                                  Apple                                Apple
# 1                                   Nike                                 Nike
# 2                          Data Engineer                              workcog
# 3                             FlexIT Inc                           FlexIT Inc
# 4                             FlexIT Inc                           FlexIT Inc
# 5    Tableau Data Engineer (100% Remote)                      Piper Companies
# 6                               Converse                             Converse
# 7                                 Twitch                               Twitch
# 8              Data Integration Engineer  The Walt Disney Company (Corporate)
# 9       Data Engineer- Chemical Insights                   McKinsey & Company
# 10                         Data Engineer                              Akshaya
# 11  Data Engineer at Rent-to-own Startup              Recruiting From Scratch
# 12                                SpaceX                               SpaceX
# 13                                Kroger                               Kroger
# 14                 Data Engineer/Analyst       First Soft Solutions [ Direct]
#
#                                            Location  \
# 0                           Seattle, WA+5 locations
# 1                        Beaverton, OR+10 locations
# 2                                +2 locationsRemote
# 3      Beaverton, OR 97005 (Central Beaverton area)
# 4      Beaverton, OR 97005 (Central Beaverton area)
# 5                                            Remote
# 6                        Remote in Boston, MA 02116
# 7                      San Francisco, CA+1 location
# 8                                       Orlando, FL
# 9               Remote in San Jose, CA+11 locations
# 10                                +1 locationRemote
# 11       Remote in Portland, OR 97035+126 locations
# 12  Redmond, WA 98052 (SE Redmond area)+2 locations
# 13                                +1 locationRemote
# 14                            Denver, CO+1 location
#
#                                           Description  \
# 0   Summary\nPosted: Jan 27, 2022\nWeekly Hours: 4...
# 1   Become a Part of the NIKE, Inc. Team\n NIKE, I...
# 2   Role: Data Engineer\nLocation: Remote\nDuratio...
# 3   We are looking for strong experience in Python...
# 4   APLA is building capabilities around the compa...
# 5   Piper Companies is currently searching for a r...
# 6   Become part of the Converse Team\n Converse is...
# 7   About Us\n\nLaunched in 2011, Twitch is a glob...
# 8   At Disney, we‘re storytellers. We make the imp...
# 9   Who You'll Work With\nYou’ll work with McKinse...
# 10  Position : Data Engineer\nClient : Adobe\nLoca...
# 11  Who is Recruiting from Scratch:\n    \n\n     ...
# 12  SpaceX was founded under the belief that a fut...
# 13  Any experience building solutions using elasti...
# 14  Client is looking for a Data Engineer (or) Ana...
#
#                                                JobUrl
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/rc/clk?jk=04d4f381c9a12...
# 2   https://www.indeed.com/company/WorkCog/jobs/Da...
# 3   https://www.indeed.com/rc/clk?jk=7ed33d932ab92...
# 4   https://www.indeed.com/rc/clk?jk=c534685069671...
# 5   https://www.indeed.com/rc/clk?jk=417f94465f37b...
# 6   https://www.indeed.com/rc/clk?jk=f59aef6085566...
# 7   https://www.indeed.com/rc/clk?jk=489dd7f31c6d7...
# 8   https://www.indeed.com/rc/clk?jk=f52cdaeedae91...
# 9   https://www.indeed.com/rc/clk?jk=3c8a220bd32bc...
# 10  https://www.indeed.com/company/AKSHAYA/jobs/Da...
# 11  https://www.indeed.com/rc/clk?jk=95dd405abd246...
# 12  https://www.indeed.com/rc/clk?jk=12eea4b44e3de...
# 13  https://www.indeed.com/company/kroger/jobs/Adv...
# 14  https://www.indeed.com/rc/clk?cmp=First-Soft-S...
# Successfully saved data_engineer jobs!")
#                           Company                     JobTitle  \
# 0                  Dennis Uniform               Dennis Uniform
# 1                   Web Developer                      Magneti
# 2                        CityCore                     CityCore
# 3            Junior Web Developer  Scorpion Internet Marketing
# 4                          1Starr                       1Starr
# 5                             USC                          USC
# 6          Web Developer (remote)                     Diib Inc
# 7                 Jr UI Developer                   Xtivia Inc
# 8                    More Seconds                 More Seconds
# 9                      Crunchapps                   Crunchapps
# 10       Javascript Web Developer             Red Van Workshop
# 11           E-Commerce Developer             Green Body Brand
# 12  Front-End Developer (Flutter)                   MotionMobs
# 13    Website Developer (Shopify)            AdvertiseMint.com
# 14                        Victory                      Victory
#
#                                   Location  \
# 0        Portland, OR 97214 (Buckman area)
# 1                                   Remote
# 2                           West Slope, OR
# 3                                   Remote
# 4                                   Remote
# 5                          Los Angeles, CA
# 6                                   Remote
# 7                                   Remote
# 8                                   Remote
# 9   New York, NY 10014 (West Village area)
# 10                                  Remote
# 11                                  Remote
# 12                                  Remote
# 13                                  Remote
# 14                                  Remote
#
#                                           Description  \
# 0   COMPANY OVERVIEW\nDENNIS Uniform Founded in 19...
# 1   Job Overview\nMagneti is looking for a marketi...
# 2   Looking for a PHP/HTML Developer who has exten...
# 3   As a Junior Web Developer, you are responsible...
# 4   1Starr Enterprises looking for Web Designers w...
# 5   The Laboratory of Neuro Imaging (www.loni.usc....
# 6   Ready to be part of an awesome team? Diib is a...
# 7   Description: \n   XTIVIA - Jr UI Developer\n H...
# 8   About Our Company - More Seconds\nAt More Seco...
# 9   Join an Innovative Deep Learning team with the...
# 10  Developers Wanted\n At Red Van Workshop, you’l...
# 11  GBB is focused on helping with the elimination...
# 12  Seeking a Flutter developer to work with our i...
# 13  We are looking for an outstanding Shopify Web ...
# 14  About the Web Developer position\nWe are looki...
#
#                                                JobUrl
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2   https://www.indeed.com/rc/clk?jk=a712b65452679...
# 3   https://www.indeed.com/company/Scorpion-Intern...
# 4   https://www.indeed.com/company/1Starr/jobs/Web...
# 5   https://www.indeed.com/rc/clk?jk=dbd51e1593e90...
# 6   https://www.indeed.com/company/Diib/jobs/Web-D...
# 7   https://www.indeed.com/rc/clk?jk=b4296f4c31188...
# 8   https://www.indeed.com/company/More-Seconds/jo...
# 9   https://www.indeed.com/rc/clk?jk=9e76e485b48fe...
# 10  https://www.indeed.com/rc/clk?jk=67052ac28cada...
# 11  https://www.indeed.com/company/Plantarion-LLC/...
# 12  https://www.indeed.com/company/MotionMobs/jobs...
# 13  https://www.indeed.com/company/AdvertiseMint.c...
# 14  https://www.indeed.com/rc/clk?jk=35bd1a53111c7...
# Successfully saved web_developer jobs!")
#                      Company                   JobTitle  \
# 0      Trap Door Attractions      Trap Door Attractions
# 1                    Infosys                    Infosys
# 2                 Party City                 Party City
# 3                  ViQi, Inc                  ViQi, Inc
# 4                    Averity                    Averity
# 5   Java developer (Backend)      CA-One Tech Cloud Inc
# 6      PWCC Marketplace, LLC      PWCC Marketplace, LLC
# 7          Backend Developer                   Actalent
# 8          Backend Developer                 Pepperdata
# 9          Backend Developer         Five Pack Creative
# 10               Customer.io                Customer.io
# 11            Charles Schwab             Charles Schwab
# 12                   Infosys                    Infosys
# 13         Backend Developer  Exodus Integrity Services
# 14                  Mathison                   Mathison
#
#                               Location  \
# 0                               Remote
# 1                               Remote
# 2                               Remote
# 3    Remote in Santa Barbara, CA 93117
# 4                    +1 locationRemote
# 5       Sunnyvale, CA 94043+1 location
# 6         Remote in Portland, OR 97224
# 7     San Carlos, CA 94070+2 locations
# 8                      Santa Clara, CA
# 9                               Remote
# 10              Remote in Portland, OR
# 11  Remote in Westlake, TX+2 locations
# 12                              Remote
# 13             Remote in Cleveland, OH
# 14                   +1 locationRemote
#
#                                           Description  \
# 0   Trap Door Escape and Madness Distillery have b...
# 1   Infosys is seeking a JAVA BACKEND DEVELOPER. T...
# 2   Company Overview: \nParty City Holdings, Inc. ...
# 3   COMPANY: ViQi, Inc.\nPOSITION: Backend Develop...
# 4   Are you a Senior Software Engineer with Golang...
# 5   Position Title: Java developer\nLocation: Bay ...
# 6   Company Overview: \nWe are PWCC. We're based i...
# 7   Equivalent Experience \n \n\nDescription:\n We...
# 8   Job Description\n\n\nBackend Developer\n Peppe...
# 9   Back-End Developer needed for full-time contra...
# 10  Hi, I'm Julia, Engineering Manager at Customer...
# 11  Your Opportunity\n\n This role can be remote.\...
# 12  Infosys is seeking a React developer to help m...
# 13  Exodus Integrity Services, Inc is a rapidly ex...
# 14  The Role:\n\n\n We’re moving fast! More than e...
#
#                                                JobUrl
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3   https://www.indeed.com/company/ViQi,-Inc/jobs/...
# 4   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 5   https://www.indeed.com/company/CA--One-Tech-Cl...
# 6   https://www.indeed.com/company/PWCC-Marketplac...
# 7   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 8   https://www.indeed.com/rc/clk?jk=de697975ea931...
# 9   https://www.indeed.com/company/Five-Pack-Creat...
# 10  https://www.indeed.com/rc/clk?jk=74e77a73f5de0...
# 11  https://www.indeed.com/rc/clk?jk=ed41f775cbc7d...
# 12  https://www.indeed.com/rc/clk?jk=0b23f771c54dc...
# 13  https://www.indeed.com/rc/clk?jk=e64bbc593c4aa...
# 14  https://www.indeed.com/rc/clk?jk=a52b9d5759e6b...
# Successfully saved backend_developer jobs!")
#                                               Company                JobTitle  \
# 0                                          DemandJump              DemandJump
# 1                                             Trovata                 Trovata
# 2                                     DevOps Engineer                 Verizon
# 3                            DevOps Engineer (remote)                  DNA325
# 4                        Dev Ops Engineer - RDNA - CW  Wellstone Technologies
# 5                                     DevOps Engineer                RIIM LLC
# 6                                               Apple                   Apple
# 7                                              Noodle                  Noodle
# 8                                     DevOps Engineer            Infologitech
# 9                                     DevOps Engineer   Resourznet Consulting
# 10                                            Verizon                 Verizon
# 11                                         TransUnion              TransUnion
# 12  DevOps Engineer (100% Remote) (Full time perma...              Aptivacorp
# 13                                AWS Devops Engineer               ACS Group
# 14                                AWS DevOps Engineer          Merit Staffing
#
#                                              Location  \
# 0                                   Remote+1 location
# 1                                              Remote
# 2   Portland, OR 97209 (Goose Hollow area)+45 loca...
# 3                                              Remote
# 4                                              Remote
# 5                                        New York, NY
# 6                             Austin, TX+22 locations
# 7           Remote in Portland, OR 97218+17 locations
# 8                                              Remote
# 9                                              Remote
# 10    Beaverton, OR 97008 (Greenway area)+2 locations
# 11                            Portland, OR+1 location
# 12                                             Remote
# 13              Remote in Vernon Hills, IL+1 location
# 14                                             Remote
#
#                                           Description  \
# 0   DevOps Engineer\nWhat Does DemandJump Solve?\n...
# 1   Company Overview: Trovata is the first modern ...
# 2   When you join Verizon\n\nVerizon is one of the...
# 3   We are a team that offers new perspectives to ...
# 4   [Notes before you apply: \nOur Policy is to ta...
# 5   We have an excellent opportunity to discuss. B...
# 6   Summary\nPosted: Oct 20, 2021\nWeekly Hours: 4...
# 7   DevOps Engineer\n Online education is no longe...
# 8   Apply Only US Citizens & GC Holders\nSkill Req...
# 9   AWS DevOps Engineer with EKS Experienceclient ...
# 10  When you join Verizon\n\nVerizon is one of the...
# 11  TransUnion's Job Applicant Privacy Notice\n   ...
# 12  Position: Site Reliability EngineerType: Full ...
# 13  Title: AWS DevOps Engineer  Location: Remote  ...
# 14  This is a perm remote opportunity with a clien...
#
#                                                JobUrl
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2   https://www.indeed.com/rc/clk?jk=443b0e2e59e76...
# 3   https://www.indeed.com/company/DNA325/jobs/Dev...
# 4   https://www.indeed.com/company/Wellstone-Techn...
# 5   https://www.indeed.com/company/RIIM-LLC/jobs/D...
# 6   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 7   https://www.indeed.com/rc/clk?jk=6da69b4b6f787...
# 8   https://www.indeed.com/company/Infologitech/jo...
# 9   https://www.indeed.com/company/Resourznet-Cons...
# 10  https://www.indeed.com/rc/clk?jk=4ad806183482f...
# 11  https://www.indeed.com/rc/clk?jk=ded9ee09e0b7e...
# 12  https://www.indeed.com/company/aptivacorp/jobs...
# 13  https://www.indeed.com/rc/clk?jk=529d3d34866b0...
# 14  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# Successfully saved devops jobs!")
